# %%
import pandas as pd
import numpy as np

# %%
df_earthquake = pd.read_csv("Japan.csv")

# %%
df_earthquake2 = pd.read_csv("Japan2.csv")

# %%
df_earthquake2 = df_earthquake2.rename(columns={"latitude": "Lat", "longitude": "Lon"})
df_earthquake2
# Out:
#                         time      Lat       Lon   depth  mag magType  nst  \
# 0   2022-02-18T02:55:07.832Z  38.2149  141.6890   56.19  5.1     mww  NaN
# 1   2022-02-21T01:12:51.371Z  36.2176  140.9840   36.09  4.6      mb  NaN
# 2   2022-02-21T02:38:57.723Z  35.9190  140.8058   55.77  4.5      mb  NaN
# 3   2022-02-21T19:28:09.552Z  37.5028  142.3713   35.00  4.3      mb  NaN
# 4   2022-02-22T02:05:20.750Z  37.8232  141.4295   67.46  4.4      mb  NaN
# 5   2022-02-23T10:16:29.366Z  39.8088  141.6777   63.37  4.3      mb  NaN
# 6   2022-02-23T19:33:03.004Z  35.9114  140.6972   88.53  4.4      mb  NaN
# 7   2022-02-24T05:18:42.569Z  37.4387  142.9431   36.79  4.7      mb  NaN
# 8   2022-02-24T23:46:55.661Z  38.1917  140.5113  123.65  4.4      mb  NaN
# 9   2022-02-25T23:31:57.223Z  37.2116  142.0414   35.00  4.8      mb  NaN
# 10  2022-02-26T05:49:52.386Z  39.3263  142.4203   51.55  4.9      mb  NaN
# 11  2022-03-02T00:08:01.016Z  36.1458  140.0922   45.67  4.0      mb  NaN
# ...

# %%
frames = [df_earthquake, df_earthquake2, df_hostel]
df = pd.concat(frames)
df
# Out:
#                         time      Lat       Lon   depth  mag magType  nst  \
# 0   2022-03-16T14:36:33.264Z  37.7015  141.5870   63.07  7.3     mww  NaN
# 1   2022-03-16T14:34:27.351Z  37.6327  141.6846   56.32  6.4     mww  NaN
# 2   2022-03-16T02:06:24.804Z  37.4375  142.9845   28.84  4.1      mb  NaN
# 3   2022-03-11T11:13:06.068Z  35.5867  142.7305   10.00  4.8      mb  NaN
# 4   2022-03-10T14:12:38.046Z  36.0175  139.8184   62.43  4.4      mb  NaN
# 5   2022-03-10T12:40:54.178Z  39.4097  143.6864   34.74  4.4      mb  NaN
# 0   2022-02-18T02:55:07.832Z  38.2149  141.6890   56.19  5.1     mww  NaN
# 1   2022-02-21T01:12:51.371Z  36.2176  140.9840   36.09  4.6      mb  NaN
# 2   2022-02-21T02:38:57.723Z  35.9190  140.8058   55.77  4.5      mb  NaN
# 3   2022-02-21T19:28:09.552Z  37.5028  142.3713   35.00  4.3      mb  NaN
# 4   2022-02-22T02:05:20.750Z  37.8232  141.4295   67.46  4.4      mb  NaN
# 5   2022-02-23T10:16:29.366Z  39.8088  141.6777   63.37  4.3      mb  NaN
# ...

# %%
df_hostel = pd.read_csv("Hostel.csv")

# %%
df_hostel = df_hostel.rename(columns={"lat": "Lat", "lon": "Lon"})

# %%
frames = [df_earthquake, df_earthquake2, df_hostel]
df = pd.concat(frames)
df
# Out:
#                          time        Lat         Lon  depth  mag magType  nst  \
# 0    2022-03-16T14:36:33.264Z  37.701500  141.587000  63.07  7.3     mww  NaN
# 1    2022-03-16T14:34:27.351Z  37.632700  141.684600  56.32  6.4     mww  NaN
# 2    2022-03-16T02:06:24.804Z  37.437500  142.984500  28.84  4.1      mb  NaN
# 3    2022-03-11T11:13:06.068Z  35.586700  142.730500  10.00  4.8      mb  NaN
# 4    2022-03-10T14:12:38.046Z  36.017500  139.818400  62.43  4.4      mb  NaN
# ..                        ...        ...         ...    ...  ...     ...  ...
# 337                       NaN  35.702908  139.668125    NaN  NaN     NaN  NaN
# 338                       NaN  35.706513  139.667695    NaN  NaN     NaN  NaN
# 339                       NaN  35.752885  139.869197    NaN  NaN     NaN  NaN
# 340                       NaN  34.997376  135.749063    NaN  NaN     NaN  NaN
# 341                       NaN  35.655470  139.742116    NaN  NaN     NaN  NaN
#
# ...

# %%
df.to_excel("Main.xlsx")
